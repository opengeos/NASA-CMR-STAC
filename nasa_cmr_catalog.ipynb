# %% [markdown]
# [![Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/NASA-CMR-STAC/blob/master/nasa_cmr_catalog.ipynb)
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/NASA-CMR-STAC/HEAD?labpath=nasa_cmr_catalog.ipynb)
# [![License](https://img.shields.io/badge/License-MIT-yellow.svg)](https://opensource.org/licenses/MIT)

# %%
import pandas as pd

# %%
url = 'https://github.com/giswqs/NASA-CMR-STAC/raw/master/nasa_cmr_catalog.tsv'
df = pd.read_csv(url, sep='\t')

# %%
df
# Out:
#                                                     id  \
# 0                 0f4324af-fa0a-4aaf-9b97-89a4f3325ce1
# 1                     11c5f6df1abc41968d0b28fe36393c9d
# 2    12-hourly_interpolated_surface_position_from_b...
# 3    12-hourly_interpolated_surface_velocity_from_b...
# 4    12_hourly_interpolated_surface_air_pressure_fr...
# ..                                                 ...
# 377       gov.noaa.nodc:GHRSST-VIIRS_NPP-NAVO-L2P.v3.0
# 378              latent-reserves-in-the-swiss-nfi.v1.0
# 379                             law_dome_annual_msa.v1
# 380                            mbs_wilhelm_msa_hooh.v1
# 381                    urn:ogc:def:EOP:VITO:VGT_S10.v1
#
#                                                  title     catalog  \
# 0                DESIS - Hyperspectral Images - Global       FEDEO
# 1    ESA Aerosol Climate Change Initiative (Aerosol...       FEDEO
# 2    12-Hourly Interpolated Surface Position from B...      SCIOPS
# 3    12-Hourly Interpolated Surface Velocity from B...      SCIOPS
# 4    12 Hourly Interpolated Surface Air Pressure fr...      SCIOPS
# ..                                                 ...         ...
# 377  GHRSST Level 2P 1 m Depth Global Sea Surface T...  GHRSSTCWIC
# 378             'Latent reserves' within the Swiss NFI      SCIOPS
# 379  150 year MSA sea ice proxy record from Law Dom...     AU_AADC
# 380  15 year Wilhelm II Land MSA and HOOH shallow i...     AU_AADC
# 381  10 Days Synthesis of SPOT VEGETATION Images (V...       FEDEO
#
#      state_date    end_date                                          bbox  \
# 0    2018-08-30         NaN                            -180, -52, 180, 52
# 1    2008-01-01  2008-12-31                            -180, -90, 180, 90
# 2    1979-01-01  2009-12-01                             -180, 60, 180, 90
# 3    1979-01-01  2009-12-02                             -180, 74, 180, 90
# 4    1979-01-01  2007-11-30                             -180, 70, 180, 90
# ..          ...         ...                                           ...
# 377  2013-06-28         NaN                            -180, -90, 180, 90
# 378  2020-01-01  2020-01-01         5.95587, 45.81802, 10.49203, 47.80838
# 379  1841-01-01  1995-12-31  112.806946, -66.76972, 112.806946, -66.76972
# 380  1984-01-01  1998-12-31                86.082, -69.13, 86.084, -69.12
# 381  1998-04-01  2014-05-31                            -180, -56, 180, 75
#
#                                            description       license
# 0    The hyperspectral instrument DESIS (DLR Earth ...  not-provided
# 1    The ESA Climate Change Initiative Aerosol proj...  not-provided
# 2    This data set contains Arctic Ocean daily buoy...  not-provided
# 3    This data set contains 12-hourly interpolated ...  not-provided
# 4    Optimally interpolated atmospheric surface pre...  not-provided
# ..                                                 ...           ...
# 377  A global Group for High Resolution Sea Surface...  not-provided
# 378  The files refer to the data used in Portier et...  not-provided
# 379  This MSA record (1841-1995) is from a Law Dome...  not-provided
# 380  This work presents results from a short firn c...  not-provided
# 381  The VGT-S10 are near-global or continental, 10...  not-provided
#
# [382 rows x 8 columns]
